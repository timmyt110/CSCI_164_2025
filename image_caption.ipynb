# %% [markdown]
# <a href="https://colab.research.google.com/github/timmyt110/CSCI_164_2025/blob/main/image_caption.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import warnings
warnings.filterwarnings(action = 'ignore')

# %%
from transformers import pipeline
from transformers.utils import logging
logging.set_verbosity(40)

# %%
from IPython.display import Image

# %%
# Image file 1: https://drive.google.com/file/d/1LElabNifJrVWNwdjTuY8IJUlL9E8IdTp/view?usp=drive_link
# !gdown 1LElabNifJrVWNwdjTuY8IJUlL9E8IdTp
file_name1 = "dice.jpg"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1LElabNifJrVWNwdjTuY8IJUlL9E8IdTp
# To: /content/dice.jpg
# 100% 71.6k/71.6k [00:00<00:00, 75.2MB/s]

# %%
# Image file 2: https://drive.google.com/file/d/1UGkuEQjLKFhqaAqM-vxP0VHc1G7UqUq-/view?usp=drive_link
# !gdown 1UGkuEQjLKFhqaAqM-vxP0VHc1G7UqUq-
file_name2 = "dancing.jpg"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1UGkuEQjLKFhqaAqM-vxP0VHc1G7UqUq-
# To: /content/dancing.jpg
# 100% 22.6k/22.6k [00:00<00:00, 50.6MB/s]

# %%
# Image file 3: https://drive.google.com/file/d/1VzbsvxuXVPL8L-IAseddRW6mEiaDSyp2/view?usp=sharing
# !gdown 1VzbsvxuXVPL8L-IAseddRW6mEiaDSyp2
file_name3 = "pets.jpg"
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1VzbsvxuXVPL8L-IAseddRW6mEiaDSyp2
# To: /content/pets.jpg
# 100% 4.20k/4.20k [00:00<00:00, 14.4MB/s]

# %%
### Task: Image captioning
captioner = pipeline(task="image-to-text", model="nlpconnect/vit-gpt2-image-captioning")
# Out:
# config.json:   0%|          | 0.00/4.61k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/982M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/241 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/120 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/228 [00:00<?, ?B/s]

# %%
file_name = file_name1

# %%
captioner2 = pipeline("image-to-text", model="Salesforce/blip-image-captioning-base")
# Out:
# config.json:   0%|          | 0.00/4.56k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/990M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/506 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/287 [00:00<?, ?B/s]

# %%
captioner3 = pipeline("image-to-text", model="microsoft/git-base-coco")
# Out:
# config.json:   0%|          | 0.00/2.82k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/707M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/141 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/453 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/503 [00:00<?, ?B/s]

# %%
captioner(file_name1)
# Out:
# [{'generated_text': 'a small white and blue toy train with a bunch of small white and blue toy train '}]

# %%
captioner2(file_name1)
# Out:
# [{'generated_text': 'three wooden dice on a black background'}]

# %%
captioner3(file_name1)
# Out:
# [{'generated_text': 'a close up of a pair of dice on a table'}]

# %%
captioner(file_name2)
# Out:
# [{'generated_text': 'a woman jumping up in the air with a tennis racket '}]

# %%
captioner2(file_name2)
# Out:
# [{'generated_text': 'two dancers in the air'}]

# %%
captioner3(file_name2)
# Out:
# [{'generated_text': 'the female ballet dancers jumping in the studio'}]

# %%
captioner(file_name3)
# Out:
# [{'generated_text': 'a white dog laying on a white surface '}]

# %%
captioner2(file_name3)
# Out:
# [{'generated_text': 'a puppy and a kitten laying on a white surface'}]

# %%
captioner3(file_name3)
# Out:
# [{'generated_text': 'a puppy and a cat lying together on a white background'}]

# %%
print(captioner2(file_name1))
display(Image(filename=file_name1))
# Out:
# [{'generated_text': 'three wooden dice on a black background'}]

# %%
display(Image(filename=file_name2))
captioner(file_name2)
# Out:
# [{'generated_text': 'a woman jumping up in the air with a tennis racket '}]

# %%
display(Image(filename=file_name3))
captioner3(file_name3)
# Out:
# [{'generated_text': 'a puppy and a cat lying together on a white background'}]
